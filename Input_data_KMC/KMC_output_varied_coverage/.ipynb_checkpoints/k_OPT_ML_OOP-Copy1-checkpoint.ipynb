# %%
import glob, os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import shutil

# %%
# %%time
from main_ML import *
ML = ML_Fitting('Atomic_sw.csv','Stoich_sw.csv','Param_sw.csv','KMC_NonDynamic_Data_iCovg_iRates_sw.csv','KMC')
ML.MKM.set_rxnconditions(Pr=[(1.0e-4*0.1),(1.0e-4*1.0e-5), 0]) #From KMC #Make sure it matches 02 CO CO2
ML.KMC_Input_Folders_Initialization()
# Out:
# Mass is conserved.
#
# Mass is conserved.
#
#
#  Number of simulations: 54
#  Input Files are Initialized.
#  SIMULATIONS MATCH AS EXPECTED
#
#
#  Number of simulations: 54
#  Input Files are Initialized.
#  SIMULATIONS MATCH AS EXPECTED
#
# CPU times: user 10.5 s, sys: 151 ms, total: 10.6 s
# Wall time: 10.9 s

# %% [raw]
# # Dictionaries to be used
#
# data_KMC_dict = {'init_covg': init_coverages,
#                     'sim_time': KMC_time_Array,
#                      'covg_prof': Covg,
#                      'iRates': Rates}
#
# data_MKM_dict = {'init_covg': MKM_init_coverages,
#                     'sim_time': time_MKM_Array,
#                      'covg_prof': MKM_Covg,
#                      'iRates': MKM_Rates}

# %%
# %%time
KMC_data = ML.KMC_Dictionary()
# Out:
# CPU times: user 3.48 s, sys: 28.9 ms, total: 3.51 s
# Wall time: 3.51 s

# %%
exp_df = ML.Exp_Dataframe()

# %%
exp_df
# Out:
#       Sim_ndex      Sim_names  Init_Covg_O*  Init_Covg_CO*  Init_Covg_O2*  \
# 0            0   Sim_A_0_B_77      0.777724       0.000000            0.0
# 1            0   Sim_A_0_B_77      0.777724       0.000000            0.0
# 2            0   Sim_A_0_B_77      0.777724       0.000000            0.0
# 3            0   Sim_A_0_B_77      0.777724       0.000000            0.0
# 4            0   Sim_A_0_B_77      0.777724       0.000000            0.0
# ...        ...            ...           ...            ...            ...
# 27495       54  Sim_A_33_B_44      0.444444       0.333333            0.0
# 27496       54  Sim_A_33_B_44      0.444444       0.333333            0.0
# 27497       54  Sim_A_33_B_44      0.444444       0.333333            0.0
# 27498       54  Sim_A_33_B_44      0.444444       0.333333            0.0
# 27499       54  Sim_A_33_B_44      0.444444       0.333333            0.0
#
#        Init_Covg_*  Time  KMC_Covg_O*  KMC_Covg_CO*  KMC_Covg_O2*  KMC_Covg_*  \
# 0         0.222276   0.0     0.777724      0.000000           0.0    0.222276
# 1         0.222276   0.1     0.777452      0.001139           0.0    0.221408
# 2         0.222276   0.2     0.777344      0.002441           0.0    0.220215
# 3         0.222276   0.3     0.776530      0.003581           0.0    0.219889
# 4         0.222276   0.4     0.775065      0.003743           0.0    0.221191
# ...            ...   ...          ...           ...           ...         ...
# 27495     0.222222  49.5     0.397244      0.014757           0.0    0.587999
# 27496     0.222222  49.6     0.398058      0.014811           0.0    0.587131
# 27497     0.222222  49.7     0.400391      0.015571           0.0    0.584039
# 27498     0.222222  49.8     0.400933      0.014757           0.0    0.584310
# 27499     0.222222  49.9     0.399957      0.015571           0.0    0.584473
#
#        KMC_iRates_O2  KMC_iRates_CO  KMC_iRates_CO2
# 0           0.000543      -0.013021        0.002441
# 1          -0.000543      -0.015191        0.002984
# 2          -0.000543      -0.017904        0.005697
# 3           0.000000      -0.017904        0.011393
# 4           0.000000      -0.016547        0.013835
# ...              ...            ...             ...
# 27495      -0.024957      -0.045573        0.050998
# 27496      -0.029297      -0.046929        0.042860
# 27497      -0.030111      -0.045573        0.045844
# 27498      -0.023872      -0.049913        0.049913
# 27499      -0.013021      -0.059679        0.043403
#
# [27500 rows x 14 columns]

# %%
# %%time
params_ = np.array([5.60983514e+07, 6.26873886e-10, 2.09163588e+04, 8.74022929e+09, 1.03443448e+10, 2.75903622e-01, 1.03031697e+08, 5.00000000e+02])

exp_mkm_df = ML.Exp_MKM_Dataframe(params = params_)
exp_mkm_df
# Out:
# CPU times: user 3min 7s, sys: 622 ms, total: 3min 8s
# Wall time: 3min 8s
#       Sim_ndex      Sim_names  Init_Covg_O*  Init_Covg_CO*  Init_Covg_O2*  \
# 0            0   Sim_A_0_B_77      0.777724       0.000000            0.0
# 1            0   Sim_A_0_B_77      0.777724       0.000000            0.0
# 2            0   Sim_A_0_B_77      0.777724       0.000000            0.0
# 3            0   Sim_A_0_B_77      0.777724       0.000000            0.0
# 4            0   Sim_A_0_B_77      0.777724       0.000000            0.0
# ...        ...            ...           ...            ...            ...
# 27495       54  Sim_A_33_B_44      0.444444       0.333333            0.0
# 27496       54  Sim_A_33_B_44      0.444444       0.333333            0.0
# 27497       54  Sim_A_33_B_44      0.444444       0.333333            0.0
# 27498       54  Sim_A_33_B_44      0.444444       0.333333            0.0
# 27499       54  Sim_A_33_B_44      0.444444       0.333333            0.0
#
#        Init_Covg_*  Time  KMC_Covg_O*  KMC_Covg_CO*  KMC_Covg_O2*  ...  \
# 0         0.222276   0.0     0.777724      0.000000           0.0  ...
# 1         0.222276   0.1     0.777452      0.001139           0.0  ...
# 2         0.222276   0.2     0.777344      0.002441           0.0  ...
# 3         0.222276   0.3     0.776530      0.003581           0.0  ...
# 4         0.222276   0.4     0.775065      0.003743           0.0  ...
# ...            ...   ...          ...           ...           ...  ...
# 27495     0.222222  49.5     0.397244      0.014757           0.0  ...
# 27496     0.222222  49.6     0.398058      0.014811           0.0  ...
# 27497     0.222222  49.7     0.400391      0.015571           0.0  ...
# 27498     0.222222  49.8     0.400933      0.014757           0.0  ...
# 27499     0.222222  49.9     0.399957      0.015571           0.0  ...
#
#        KMC_iRates_O2  KMC_iRates_CO  KMC_iRates_CO2  MKM_Covg_O*  \
# 0           0.000543      -0.013021        0.002441     0.770000
# 1          -0.000543      -0.015191        0.002984     0.746245
# 2          -0.000543      -0.017904        0.005697     0.724674
# 3           0.000000      -0.017904        0.011393     0.705010
# 4           0.000000      -0.016547        0.013835     0.687022
# ...              ...            ...             ...          ...
# 27495      -0.024957      -0.045573        0.050998     0.435818
# 27496      -0.029297      -0.046929        0.042860     0.435818
# 27497      -0.030111      -0.045573        0.045844     0.435818
# 27498      -0.023872      -0.049913        0.049913     0.435818
# 27499      -0.013021      -0.059679        0.043403     0.435818
#
#        MKM_Covg_CO*  MKM_Covg_O2*  MKM_Covg_*  MKM_iRates_O2  MKM_iRates_CO  \
# 0      0.000000e+00  0.000000e+00    0.230000      -0.048108      -0.012903
# 1      1.851449e-10  1.818909e-11    0.253755       0.105901      -0.014235
# 2      2.068636e-10  1.747295e-11    0.275326       0.095129      -0.015445
# 3      2.278200e-10  1.686238e-11    0.294990       0.085680      -0.016548
# 4      2.480413e-10  1.633778e-11    0.312978       0.077332      -0.017558
# ...             ...           ...         ...            ...            ...
# 27495  7.048435e-10  1.169093e-11    0.564182      -0.015825      -0.031650
# 27496  7.048435e-10  1.169093e-11    0.564182      -0.015825      -0.031650
# 27497  7.048435e-10  1.169093e-11    0.564182      -0.015825      -0.031650
# 27498  7.048435e-10  1.169093e-11    0.564182      -0.015825      -0.031650
# 27499  7.048435e-10  1.169093e-11    0.564182      -0.015825      -0.031650
#
#        MKM_iRates_CO2
# 0            0.000000
# 1            0.014235
# 2            0.015445
# 3            0.016548
# 4            0.017558
# ...               ...
# 27495        0.031650
# 27496        0.031650
# 27497        0.031650
# 27498        0.031650
# 27499        0.031650
#
# [27500 rows x 21 columns]

# %%
# %%time
#Plotting  fit comparison
ML.MKM.k = params_

ML.Fit_Visualization(params = params_,Comp='Covg')

# %%
# %%time
# %matplotlib notebook
#plotting 3D KMC
ML.three_d_plot_Exp_only(p_c = 0.1,Comp='Covg')

# %%
# %%time
# %matplotlib notebook
#plotting 3D KMC
ML.three_d_plot_Exp_only(p_c = 0.1,Comp='iRates')

# %%
# %%time
ML.three_d_plot_Covg(p_c = 0.1)

# %%
# %%time
ML.three_d_plot_iRates(p_c = 0.1)

# %%
# %%time
X_all,Y_all = ML.X_Y_full_dataset() #Full Regression Dataset for ML

# %%
X_all

# %%
Y_all

# %%
# %%time
Ext = ML.External_Dataframe() #corresponding MKM Dataframe corresponding to obtained as a result of external input file to be used on ML model
Ext

# %%
# %%time
RMSE_Dataframe = ML.Fit_Evaluation_RMSE()
RMSE_Dataframe

# %%
# %%time
ML.ML_Fitting(alg = 'KNN', test_train_split=0.1, plot=True)
