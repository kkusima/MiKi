# %%
import glob, os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import shutil
# %matplotlib notebook
from main import *

# %%
#Extracting the SS coverages previously saved and extracted from kMC files
ss_COVG_NONLAT = pd.read_csv('SS_Covg_nonLat.csv')
ss_COVG_LAT = pd.read_csv('SS_Covg_Lat.csv')

# %%
#Isolating pressures and ss coverages
Prs_non_lat = ss_COVG_NONLAT.iloc[:,0].to_numpy()
Prs_lat = ss_COVG_LAT.iloc[:,0].to_numpy()
ss_covg_non_lat = ss_COVG_NONLAT.iloc[:,1].to_numpy()
ss_covg_lat = ss_COVG_LAT.iloc[:,1].to_numpy()

# %%
#Simulation times from each kMC simulation
t0,tf = 0,750.000000000102

# %%
# %%time
#Performing SS MIKI MKM simulations for non lateral case
from main import *
MKM = MKModel('Atomic.csv','Stoich.csv','Param.csv')
MKM.Thermo_Constraint = 'OFF'
MKM.set_limits_of_integration(t0,tf)
MKM.rate_const_correction='None'
MKM_SS_covg_NONLAT = []
Prs = Prs_non_lat
for i in np.arange(len(Prs)):
    MKM.set_rxnconditions(Pr=[Prs[i]])
    MKM_SS_covg_NONLAT = np.append(MKM_SS_covg_NONLAT,MKM.get_SS_coverages(print_warning=False)[0])
# Out:
# Mass is conserved.
#
# CPU times: user 2.96 s, sys: 8.68 ms, total: 2.96 s
# Wall time: 2.98 s

# %%
from pandas import read_csv
import math
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)
# fix random seed for reproducibilityz
tf.random.set_seed(7)
# load the dataset
dataframe = pd.DataFrame(ss_covg_lat)
dataset = dataframe.values
dataset = dataset.astype('float32')
# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
# split into train and test sets
train_size = int(len(dataset) * 0.50)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
# reshape into X=t and Y=t+1
look_back = 1
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)
# reshape input to be [samples, time steps, features]
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))
# create and fit the LSTM network
model = Sequential()
model.add(LSTM(4, input_shape=(1, look_back)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=2)
# make predictions
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)
# invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])
# calculate root mean squared error
trainScore = np.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = np.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# shift train predictions for plotting
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
# shift test predictions for plotting
testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict
# Out:
# 2023-09-05 02:39:51.798231: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/100
# 12/12 - 1s - loss: 0.2957 - 870ms/epoch - 73ms/step
# Epoch 2/100
# 12/12 - 0s - loss: 0.2733 - 19ms/epoch - 2ms/step
# Epoch 3/100
# 12/12 - 0s - loss: 0.2510 - 18ms/epoch - 2ms/step
# Epoch 4/100
# 12/12 - 0s - loss: 0.2311 - 17ms/epoch - 1ms/step
# Epoch 5/100
# 12/12 - 0s - loss: 0.2107 - 20ms/epoch - 2ms/step
# Epoch 6/100
# 12/12 - 0s - loss: 0.1928 - 19ms/epoch - 2ms/step
# Epoch 7/100
# 12/12 - 0s - loss: 0.1740 - 19ms/epoch - 2ms/step
# Epoch 8/100
# 12/12 - 0s - loss: 0.1567 - 26ms/epoch - 2ms/step
# Epoch 9/100
# 12/12 - 0s - loss: 0.1396 - 29ms/epoch - 2ms/step
# Epoch 10/100
# 12/12 - 0s - loss: 0.1231 - 29ms/epoch - 2ms/step
# Epoch 11/100
# 12/12 - 0s - loss: 0.1078 - 19ms/epoch - 2ms/step
# Epoch 12/100
# 12/12 - 0s - loss: 0.0934 - 21ms/epoch - 2ms/step
# Epoch 13/100
# 12/12 - 0s - loss: 0.0799 - 16ms/epoch - 1ms/step
# Epoch 14/100
# 12/12 - 0s - loss: 0.0681 - 17ms/epoch - 1ms/step
# Epoch 15/100
# 12/12 - 0s - loss: 0.0577 - 23ms/epoch - 2ms/step
# Epoch 16/100
# 12/12 - 0s - loss: 0.0477 - 15ms/epoch - 1ms/step
# Epoch 17/100
# 12/12 - 0s - loss: 0.0392 - 16ms/epoch - 1ms/step
# Epoch 18/100
# 12/12 - 0s - loss: 0.0331 - 16ms/epoch - 1ms/step
# Epoch 19/100
# 12/12 - 0s - loss: 0.0267 - 19ms/epoch - 2ms/step
# Epoch 20/100
# 12/12 - 0s - loss: 0.0227 - 16ms/epoch - 1ms/step
# Epoch 21/100
# 12/12 - 0s - loss: 0.0192 - 18ms/epoch - 2ms/step
# Epoch 22/100
# 12/12 - 0s - loss: 0.0160 - 21ms/epoch - 2ms/step
# Epoch 23/100
# 12/12 - 0s - loss: 0.0142 - 27ms/epoch - 2ms/step
# Epoch 24/100
# 12/12 - 0s - loss: 0.0125 - 25ms/epoch - 2ms/step
# Epoch 25/100
# 12/12 - 0s - loss: 0.0117 - 27ms/epoch - 2ms/step
# Epoch 26/100
# 12/12 - 0s - loss: 0.0107 - 26ms/epoch - 2ms/step
# Epoch 27/100
# 12/12 - 0s - loss: 0.0101 - 29ms/epoch - 2ms/step
# Epoch 28/100
# 12/12 - 0s - loss: 0.0099 - 26ms/epoch - 2ms/step
# Epoch 29/100
# 12/12 - 0s - loss: 0.0095 - 26ms/epoch - 2ms/step
# Epoch 30/100
# 12/12 - 0s - loss: 0.0093 - 31ms/epoch - 3ms/step
# Epoch 31/100
# 12/12 - 0s - loss: 0.0091 - 29ms/epoch - 2ms/step
# Epoch 32/100
# 12/12 - 0s - loss: 0.0090 - 30ms/epoch - 3ms/step
# Epoch 33/100
# 12/12 - 0s - loss: 0.0089 - 27ms/epoch - 2ms/step
# Epoch 34/100
# 12/12 - 0s - loss: 0.0088 - 27ms/epoch - 2ms/step
# Epoch 35/100
# 12/12 - 0s - loss: 0.0087 - 24ms/epoch - 2ms/step
# Epoch 36/100
# 12/12 - 0s - loss: 0.0085 - 25ms/epoch - 2ms/step
# Epoch 37/100
# 12/12 - 0s - loss: 0.0084 - 27ms/epoch - 2ms/step
# Epoch 38/100
# 12/12 - 0s - loss: 0.0083 - 18ms/epoch - 1ms/step
# Epoch 39/100
# 12/12 - 0s - loss: 0.0083 - 14ms/epoch - 1ms/step
# Epoch 40/100
# 12/12 - 0s - loss: 0.0082 - 15ms/epoch - 1ms/step
# Epoch 41/100
# 12/12 - 0s - loss: 0.0081 - 22ms/epoch - 2ms/step
# Epoch 42/100
# 12/12 - 0s - loss: 0.0080 - 18ms/epoch - 2ms/step
# Epoch 43/100
# 12/12 - 0s - loss: 0.0078 - 16ms/epoch - 1ms/step
# Epoch 44/100
# 12/12 - 0s - loss: 0.0078 - 23ms/epoch - 2ms/step
# Epoch 45/100
# 12/12 - 0s - loss: 0.0077 - 15ms/epoch - 1ms/step
# Epoch 46/100
# 12/12 - 0s - loss: 0.0076 - 18ms/epoch - 2ms/step
# Epoch 47/100
# 12/12 - 0s - loss: 0.0075 - 17ms/epoch - 1ms/step
# Epoch 48/100
# 12/12 - 0s - loss: 0.0074 - 16ms/epoch - 1ms/step
# Epoch 49/100
# 12/12 - 0s - loss: 0.0073 - 19ms/epoch - 2ms/step
# Epoch 50/100
# 12/12 - 0s - loss: 0.0072 - 15ms/epoch - 1ms/step
# Epoch 51/100
# 12/12 - 0s - loss: 0.0071 - 20ms/epoch - 2ms/step
# Epoch 52/100
# 12/12 - 0s - loss: 0.0071 - 17ms/epoch - 1ms/step
# Epoch 53/100
# 12/12 - 0s - loss: 0.0070 - 15ms/epoch - 1ms/step
# Epoch 54/100
# 12/12 - 0s - loss: 0.0068 - 14ms/epoch - 1ms/step
# Epoch 55/100
# 12/12 - 0s - loss: 0.0067 - 16ms/epoch - 1ms/step
# Epoch 56/100
# 12/12 - 0s - loss: 0.0066 - 13ms/epoch - 1ms/step
# Epoch 57/100
# 12/12 - 0s - loss: 0.0066 - 19ms/epoch - 2ms/step
# Epoch 58/100
# 12/12 - 0s - loss: 0.0065 - 16ms/epoch - 1ms/step
# Epoch 59/100
# 12/12 - 0s - loss: 0.0064 - 15ms/epoch - 1ms/step
# Epoch 60/100
# 12/12 - 0s - loss: 0.0062 - 14ms/epoch - 1ms/step
# Epoch 61/100
# 12/12 - 0s - loss: 0.0062 - 13ms/epoch - 1ms/step
# Epoch 62/100
# 12/12 - 0s - loss: 0.0061 - 12ms/epoch - 971us/step
# Epoch 63/100
# 12/12 - 0s - loss: 0.0060 - 37ms/epoch - 3ms/step
# Epoch 64/100
# 12/12 - 0s - loss: 0.0059 - 21ms/epoch - 2ms/step
# Epoch 65/100
# 12/12 - 0s - loss: 0.0058 - 20ms/epoch - 2ms/step
# Epoch 66/100
# 12/12 - 0s - loss: 0.0057 - 23ms/epoch - 2ms/step
# Epoch 67/100
# 12/12 - 0s - loss: 0.0056 - 14ms/epoch - 1ms/step
# Epoch 68/100
# 12/12 - 0s - loss: 0.0055 - 15ms/epoch - 1ms/step
# Epoch 69/100
# 12/12 - 0s - loss: 0.0054 - 12ms/epoch - 1ms/step
# Epoch 70/100
# 12/12 - 0s - loss: 0.0053 - 14ms/epoch - 1ms/step
# Epoch 71/100
# 12/12 - 0s - loss: 0.0054 - 13ms/epoch - 1ms/step
# Epoch 72/100
# 12/12 - 0s - loss: 0.0052 - 15ms/epoch - 1ms/step
# Epoch 73/100
# 12/12 - 0s - loss: 0.0051 - 13ms/epoch - 1ms/step
# Epoch 74/100
# 12/12 - 0s - loss: 0.0050 - 15ms/epoch - 1ms/step
# Epoch 75/100
# 12/12 - 0s - loss: 0.0049 - 14ms/epoch - 1ms/step
# Epoch 76/100
# 12/12 - 0s - loss: 0.0049 - 15ms/epoch - 1ms/step
# Epoch 77/100
# 12/12 - 0s - loss: 0.0047 - 13ms/epoch - 1ms/step
# Epoch 78/100
# 12/12 - 0s - loss: 0.0047 - 14ms/epoch - 1ms/step
# Epoch 79/100
# 12/12 - 0s - loss: 0.0046 - 16ms/epoch - 1ms/step
# Epoch 80/100
# 12/12 - 0s - loss: 0.0045 - 16ms/epoch - 1ms/step
# Epoch 81/100
# 12/12 - 0s - loss: 0.0045 - 16ms/epoch - 1ms/step
# Epoch 82/100
# 12/12 - 0s - loss: 0.0044 - 16ms/epoch - 1ms/step
# Epoch 83/100
# 12/12 - 0s - loss: 0.0043 - 16ms/epoch - 1ms/step
# Epoch 84/100
# 12/12 - 0s - loss: 0.0042 - 16ms/epoch - 1ms/step
# Epoch 85/100
# 12/12 - 0s - loss: 0.0041 - 17ms/epoch - 1ms/step
# Epoch 86/100
# 12/12 - 0s - loss: 0.0041 - 24ms/epoch - 2ms/step
# Epoch 87/100
# 12/12 - 0s - loss: 0.0040 - 18ms/epoch - 2ms/step
# Epoch 88/100
# 12/12 - 0s - loss: 0.0039 - 18ms/epoch - 2ms/step
# Epoch 89/100
# 12/12 - 0s - loss: 0.0038 - 17ms/epoch - 1ms/step
# Epoch 90/100
# 12/12 - 0s - loss: 0.0037 - 16ms/epoch - 1ms/step
# Epoch 91/100
# 12/12 - 0s - loss: 0.0037 - 19ms/epoch - 2ms/step
# Epoch 92/100
# 12/12 - 0s - loss: 0.0036 - 15ms/epoch - 1ms/step
# Epoch 93/100
# 12/12 - 0s - loss: 0.0035 - 23ms/epoch - 2ms/step
# Epoch 94/100
# 12/12 - 0s - loss: 0.0035 - 17ms/epoch - 1ms/step
# Epoch 95/100
# 12/12 - 0s - loss: 0.0034 - 15ms/epoch - 1ms/step
# Epoch 96/100
# 12/12 - 0s - loss: 0.0033 - 14ms/epoch - 1ms/step
# Epoch 97/100
# 12/12 - 0s - loss: 0.0033 - 14ms/epoch - 1ms/step
# Epoch 98/100
# 12/12 - 0s - loss: 0.0032 - 12ms/epoch - 991us/step
# Epoch 99/100
# 12/12 - 0s - loss: 0.0032 - 14ms/epoch - 1ms/step
# Epoch 100/100
# 12/12 - 0s - loss: 0.0031 - 13ms/epoch - 1ms/step
# 1/1 [==============================] - 0s 287ms/step
# 1/1 [==============================] - 0s 19ms/step
# Train Score: 0.01 RMSE
# Test Score: 0.03 RMSE

# %%
combined = trainPredictPlot
for i in np.arange(len(trainPredictPlot)):
    if i>17:
        combined[i] = testPredictPlot[i]

# %%
plt.figure()
plt.semilogx(Prs_lat,ss_covg_lat,'o',label='kMC (With lateral interaction)')
plt.semilogx(Prs_non_lat,ss_covg_non_lat,'*',label='kMC (No lateral interaction)')
plt.semilogx(Prs_non_lat,MKM_SS_covg_NONLAT,'-',label='MKM isotherm')
# plt.semilogx(Prs_lat,MKM_SS_covg_LAT,'--',label='MKM_LAT_Fitted isotherm')
plt.semilogx(Prs_lat,combined,'--',label='Fitted LSTM')
plt.legend()
plt.title('CO adsorption_desorption isotherm')
plt.xlabel('Pressure, [bar]')
plt.ylabel('CO Coverage, [ML]')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
