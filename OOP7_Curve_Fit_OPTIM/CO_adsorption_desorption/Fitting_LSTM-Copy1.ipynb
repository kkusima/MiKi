# %%
import glob, os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import shutil
# %matplotlib notebook
from main import *

# %%
#Extracting the SS coverages previously saved and extracted from kMC files
ss_COVG_NONLAT = pd.read_csv('SS_Covg_nonLat.csv')
ss_COVG_LAT = pd.read_csv('SS_Covg_Lat.csv')

# %%
#Isolating pressures and ss coverages
Prs_non_lat = ss_COVG_NONLAT.iloc[:,0].to_numpy()
Prs_lat = ss_COVG_LAT.iloc[:,0].to_numpy()
ss_covg_non_lat = ss_COVG_NONLAT.iloc[:,1].to_numpy()
ss_covg_lat = ss_COVG_LAT.iloc[:,1].to_numpy()

# %%
#Simulation times from each kMC simulation
t0,tf = 0,750.000000000102

# %%
# %%time
#Performing SS MIKI MKM simulations for non lateral case
from main import *
MKM = MKModel('Atomic.csv','Stoich.csv','Param.csv')
MKM.Thermo_Constraint = 'OFF'
MKM.set_limits_of_integration(t0,tf)
MKM.rate_const_correction='None'
MKM_SS_covg_NONLAT = []
Prs = Prs_non_lat
for i in np.arange(len(Prs)):
    MKM.set_rxnconditions(Pr=[Prs[i]])
    MKM_SS_covg_NONLAT = np.append(MKM_SS_covg_NONLAT,MKM.get_SS_coverages(print_warning=False)[0])
# Out:
# Mass is conserved.
#
# CPU times: user 2.63 s, sys: 11.2 ms, total: 2.64 s
# Wall time: 2.67 s

# %%
from pandas import read_csv
import math
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)
# fix random seed for reproducibilityz
tf.random.set_seed(7)
# load the dataset
dataframe = pd.DataFrame(ss_covg_lat)
dataset = dataframe.values
dataset = dataset.astype('float32')
# split into train and test sets
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
# reshape dataset
look_back = 3
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)
# create and fit Multilayer Perceptron model
model = Sequential()
model.add(Dense(12, input_shape=(look_back,), activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=400, batch_size=2, verbose=2)
# Estimate model performance
trainScore = model.evaluate(trainX, trainY, verbose=0)
print('Train Score: %.2f MSE (%.2f RMSE)' % (trainScore, math.sqrt(trainScore)))
testScore = model.evaluate(testX, testY, verbose=0)
print('Test Score: %.2f MSE (%.2f RMSE)' % (testScore, math.sqrt(testScore)))
# generate predictions for training
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)
# shift train predictions for plotting
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
# shift test predictions for plotting
testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict
# plot baseline and predictions
plt.plot(dataset)
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
# Out:
# 2023-09-05 11:29:22.141956: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/400
# 7/7 - 0s - loss: 0.0566 - 186ms/epoch - 27ms/step
# Epoch 2/400
# 7/7 - 0s - loss: 0.0460 - 4ms/epoch - 554us/step
# Epoch 3/400
# 7/7 - 0s - loss: 0.0381 - 4ms/epoch - 588us/step
# Epoch 4/400
# 7/7 - 0s - loss: 0.0321 - 6ms/epoch - 897us/step
# Epoch 5/400
# 7/7 - 0s - loss: 0.0276 - 5ms/epoch - 757us/step
# Epoch 6/400
# 7/7 - 0s - loss: 0.0241 - 5ms/epoch - 754us/step
# Epoch 7/400
# 7/7 - 0s - loss: 0.0203 - 4ms/epoch - 567us/step
# Epoch 8/400
# 7/7 - 0s - loss: 0.0171 - 4ms/epoch - 581us/step
# Epoch 9/400
# 7/7 - 0s - loss: 0.0140 - 6ms/epoch - 851us/step
# Epoch 10/400
# 7/7 - 0s - loss: 0.0114 - 4ms/epoch - 589us/step
# Epoch 11/400
# 7/7 - 0s - loss: 0.0091 - 4ms/epoch - 595us/step
# Epoch 12/400
# 7/7 - 0s - loss: 0.0071 - 6ms/epoch - 800us/step
# Epoch 13/400
# 7/7 - 0s - loss: 0.0055 - 4ms/epoch - 582us/step
# Epoch 14/400
# 7/7 - 0s - loss: 0.0041 - 4ms/epoch - 556us/step
# Epoch 15/400
# 7/7 - 0s - loss: 0.0032 - 5ms/epoch - 783us/step
# Epoch 16/400
# 7/7 - 0s - loss: 0.0023 - 4ms/epoch - 608us/step
# Epoch 17/400
# 7/7 - 0s - loss: 0.0017 - 4ms/epoch - 547us/step
# Epoch 18/400
# 7/7 - 0s - loss: 0.0014 - 5ms/epoch - 647us/step
# Epoch 19/400
# 7/7 - 0s - loss: 0.0011 - 4ms/epoch - 633us/step
# Epoch 20/400
# 7/7 - 0s - loss: 9.1731e-04 - 4ms/epoch - 580us/step
# Epoch 21/400
# 7/7 - 0s - loss: 8.1241e-04 - 5ms/epoch - 733us/step
# Epoch 22/400
# 7/7 - 0s - loss: 7.5187e-04 - 4ms/epoch - 627us/step
# Epoch 23/400
# 7/7 - 0s - loss: 7.2853e-04 - 4ms/epoch - 550us/step
# Epoch 24/400
# 7/7 - 0s - loss: 7.1583e-04 - 5ms/epoch - 671us/step
# Epoch 25/400
# 7/7 - 0s - loss: 7.0716e-04 - 4ms/epoch - 598us/step
# Epoch 26/400
# 7/7 - 0s - loss: 7.1889e-04 - 4ms/epoch - 560us/step
# Epoch 27/400
# 7/7 - 0s - loss: 7.0201e-04 - 4ms/epoch - 582us/step
# Epoch 28/400
# 7/7 - 0s - loss: 6.9849e-04 - 5ms/epoch - 748us/step
# Epoch 29/400
# 7/7 - 0s - loss: 6.9694e-04 - 4ms/epoch - 583us/step
# Epoch 30/400
# 7/7 - 0s - loss: 6.9206e-04 - 4ms/epoch - 576us/step
# Epoch 31/400
# 7/7 - 0s - loss: 6.8985e-04 - 6ms/epoch - 805us/step
# Epoch 32/400
# 7/7 - 0s - loss: 6.8894e-04 - 5ms/epoch - 757us/step
# Epoch 33/400
# 7/7 - 0s - loss: 6.8861e-04 - 4ms/epoch - 560us/step
# Epoch 34/400
# 7/7 - 0s - loss: 6.8310e-04 - 5ms/epoch - 707us/step
# Epoch 35/400
# 7/7 - 0s - loss: 6.8364e-04 - 4ms/epoch - 590us/step
# Epoch 36/400
# 7/7 - 0s - loss: 6.7305e-04 - 4ms/epoch - 572us/step
# Epoch 37/400
# 7/7 - 0s - loss: 6.6825e-04 - 4ms/epoch - 537us/step
# Epoch 38/400
# 7/7 - 0s - loss: 6.6540e-04 - 5ms/epoch - 732us/step
# Epoch 39/400
# 7/7 - 0s - loss: 6.6644e-04 - 4ms/epoch - 565us/step
# Epoch 40/400
# 7/7 - 0s - loss: 5.9060e-04 - 4ms/epoch - 561us/step
# Epoch 41/400
# 7/7 - 0s - loss: 5.4331e-04 - 5ms/epoch - 680us/step
# Epoch 42/400
# 7/7 - 0s - loss: 5.3548e-04 - 4ms/epoch - 605us/step
# Epoch 43/400
# 7/7 - 0s - loss: 4.8390e-04 - 4ms/epoch - 606us/step
# Epoch 44/400
# 7/7 - 0s - loss: 4.6084e-04 - 5ms/epoch - 780us/step
# Epoch 45/400
# 7/7 - 0s - loss: 4.2909e-04 - 4ms/epoch - 574us/step
# Epoch 46/400
# 7/7 - 0s - loss: 4.1558e-04 - 4ms/epoch - 590us/step
# Epoch 47/400
# 7/7 - 0s - loss: 4.0679e-04 - 6ms/epoch - 787us/step
# Epoch 48/400
# 7/7 - 0s - loss: 4.0559e-04 - 4ms/epoch - 595us/step
# Epoch 49/400
# 7/7 - 0s - loss: 3.9259e-04 - 4ms/epoch - 626us/step
# Epoch 50/400
# 7/7 - 0s - loss: 3.3750e-04 - 5ms/epoch - 739us/step
# Epoch 51/400
# 7/7 - 0s - loss: 3.4869e-04 - 4ms/epoch - 609us/step
# Epoch 52/400
# 7/7 - 0s - loss: 3.3267e-04 - 4ms/epoch - 582us/step
# Epoch 53/400
# 7/7 - 0s - loss: 3.1240e-04 - 6ms/epoch - 790us/step
# Epoch 54/400
# 7/7 - 0s - loss: 3.1192e-04 - 4ms/epoch - 555us/step
# Epoch 55/400
# 7/7 - 0s - loss: 2.9518e-04 - 4ms/epoch - 563us/step
# Epoch 56/400
# 7/7 - 0s - loss: 2.8269e-04 - 7ms/epoch - 944us/step
# Epoch 57/400
# 7/7 - 0s - loss: 2.6837e-04 - 4ms/epoch - 571us/step
# Epoch 58/400
# 7/7 - 0s - loss: 2.5769e-04 - 4ms/epoch - 581us/step
# Epoch 59/400
# 7/7 - 0s - loss: 2.5974e-04 - 6ms/epoch - 879us/step
# Epoch 60/400
# 7/7 - 0s - loss: 2.4375e-04 - 4ms/epoch - 575us/step
# Epoch 61/400
# 7/7 - 0s - loss: 2.6065e-04 - 4ms/epoch - 600us/step
# Epoch 62/400
# 7/7 - 0s - loss: 2.3768e-04 - 5ms/epoch - 684us/step
# Epoch 63/400
# 7/7 - 0s - loss: 2.2104e-04 - 4ms/epoch - 590us/step
# Epoch 64/400
# 7/7 - 0s - loss: 2.1649e-04 - 4ms/epoch - 586us/step
# Epoch 65/400
# 7/7 - 0s - loss: 2.1365e-04 - 6ms/epoch - 910us/step
# Epoch 66/400
# 7/7 - 0s - loss: 2.1086e-04 - 4ms/epoch - 563us/step
# Epoch 67/400
# 7/7 - 0s - loss: 1.8841e-04 - 4ms/epoch - 535us/step
# Epoch 68/400
# 7/7 - 0s - loss: 1.8194e-04 - 5ms/epoch - 730us/step
# Epoch 69/400
# 7/7 - 0s - loss: 1.7586e-04 - 4ms/epoch - 577us/step
# Epoch 70/400
# 7/7 - 0s - loss: 1.7454e-04 - 4ms/epoch - 525us/step
# Epoch 71/400
# 7/7 - 0s - loss: 1.7270e-04 - 4ms/epoch - 596us/step
# Epoch 72/400
# 7/7 - 0s - loss: 1.6293e-04 - 5ms/epoch - 696us/step
# Epoch 73/400
# 7/7 - 0s - loss: 1.6313e-04 - 4ms/epoch - 524us/step
# Epoch 74/400
# 7/7 - 0s - loss: 1.5413e-04 - 6ms/epoch - 903us/step
# Epoch 75/400
# 7/7 - 0s - loss: 1.5345e-04 - 4ms/epoch - 559us/step
# Epoch 76/400
# 7/7 - 0s - loss: 1.4473e-04 - 4ms/epoch - 569us/step
# Epoch 77/400
# 7/7 - 0s - loss: 1.4200e-04 - 5ms/epoch - 655us/step
# Epoch 78/400
# 7/7 - 0s - loss: 1.3647e-04 - 4ms/epoch - 612us/step
# Epoch 79/400
# 7/7 - 0s - loss: 1.3579e-04 - 4ms/epoch - 619us/step
# Epoch 80/400
# 7/7 - 0s - loss: 1.3003e-04 - 8ms/epoch - 1ms/step
# Epoch 81/400
# 7/7 - 0s - loss: 1.2923e-04 - 5ms/epoch - 652us/step
# Epoch 82/400
# 7/7 - 0s - loss: 1.1810e-04 - 4ms/epoch - 536us/step
# Epoch 83/400
# 7/7 - 0s - loss: 1.2254e-04 - 4ms/epoch - 623us/step
# Epoch 84/400
# 7/7 - 0s - loss: 1.1917e-04 - 5ms/epoch - 664us/step
# Epoch 85/400
# 7/7 - 0s - loss: 1.1830e-04 - 4ms/epoch - 568us/step
# Epoch 86/400
# 7/7 - 0s - loss: 1.1309e-04 - 4ms/epoch - 619us/step
# Epoch 87/400
# 7/7 - 0s - loss: 1.1090e-04 - 4ms/epoch - 620us/step
# Epoch 88/400
# 7/7 - 0s - loss: 1.0779e-04 - 4ms/epoch - 560us/step
# Epoch 89/400
# 7/7 - 0s - loss: 1.2055e-04 - 4ms/epoch - 544us/step
# Epoch 90/400
# 7/7 - 0s - loss: 1.0548e-04 - 4ms/epoch - 617us/step
# Epoch 91/400
# 7/7 - 0s - loss: 1.0586e-04 - 4ms/epoch - 627us/step
# Epoch 92/400
# 7/7 - 0s - loss: 1.0372e-04 - 4ms/epoch - 581us/step
# Epoch 93/400
# 7/7 - 0s - loss: 1.0169e-04 - 6ms/epoch - 861us/step
# Epoch 94/400
# 7/7 - 0s - loss: 9.9957e-05 - 4ms/epoch - 559us/step
# Epoch 95/400
# 7/7 - 0s - loss: 1.0182e-04 - 4ms/epoch - 551us/step
# Epoch 96/400
# 7/7 - 0s - loss: 1.0969e-04 - 6ms/epoch - 798us/step
# Epoch 97/400
# 7/7 - 0s - loss: 1.0095e-04 - 4ms/epoch - 604us/step
# Epoch 98/400
# 7/7 - 0s - loss: 9.9100e-05 - 4ms/epoch - 559us/step
# Epoch 99/400
# 7/7 - 0s - loss: 9.3338e-05 - 6ms/epoch - 909us/step
# Epoch 100/400
# 7/7 - 0s - loss: 9.2163e-05 - 4ms/epoch - 599us/step
# Epoch 101/400
# 7/7 - 0s - loss: 9.3485e-05 - 4ms/epoch - 585us/step
# Epoch 102/400
# 7/7 - 0s - loss: 9.2598e-05 - 4ms/epoch - 604us/step
# Epoch 103/400
# 7/7 - 0s - loss: 9.7816e-05 - 5ms/epoch - 665us/step
# Epoch 104/400
# 7/7 - 0s - loss: 9.0590e-05 - 4ms/epoch - 563us/step
# Epoch 105/400
# 7/7 - 0s - loss: 9.5598e-05 - 4ms/epoch - 600us/step
# Epoch 106/400
# 7/7 - 0s - loss: 9.0188e-05 - 6ms/epoch - 801us/step
# Epoch 107/400
# 7/7 - 0s - loss: 9.0733e-05 - 4ms/epoch - 563us/step
# Epoch 108/400
# 7/7 - 0s - loss: 8.9721e-05 - 4ms/epoch - 578us/step
# Epoch 109/400
# 7/7 - 0s - loss: 8.6670e-05 - 5ms/epoch - 693us/step
# Epoch 110/400
# 7/7 - 0s - loss: 9.0117e-05 - 4ms/epoch - 597us/step
# Epoch 111/400
# 7/7 - 0s - loss: 9.7942e-05 - 4ms/epoch - 554us/step
# Epoch 112/400
# 7/7 - 0s - loss: 8.9408e-05 - 5ms/epoch - 780us/step
# Epoch 113/400
# 7/7 - 0s - loss: 8.8214e-05 - 4ms/epoch - 592us/step
# Epoch 114/400
# 7/7 - 0s - loss: 9.5086e-05 - 4ms/epoch - 545us/step
# Epoch 115/400
# 7/7 - 0s - loss: 9.0836e-05 - 4ms/epoch - 608us/step
# Epoch 116/400
# 7/7 - 0s - loss: 9.2622e-05 - 5ms/epoch - 689us/step
# Epoch 117/400
# 7/7 - 0s - loss: 8.1944e-05 - 4ms/epoch - 554us/step
# Epoch 118/400
# 7/7 - 0s - loss: 1.0060e-04 - 4ms/epoch - 581us/step
# Epoch 119/400
# 7/7 - 0s - loss: 7.8337e-05 - 5ms/epoch - 729us/step
# Epoch 120/400
# 7/7 - 0s - loss: 9.1840e-05 - 4ms/epoch - 569us/step
# Epoch 121/400
# 7/7 - 0s - loss: 9.1550e-05 - 4ms/epoch - 558us/step
# Epoch 122/400
# 7/7 - 0s - loss: 7.9137e-05 - 5ms/epoch - 705us/step
# Epoch 123/400
# 7/7 - 0s - loss: 7.6948e-05 - 4ms/epoch - 570us/step
# Epoch 124/400
# 7/7 - 0s - loss: 7.7248e-05 - 4ms/epoch - 558us/step
# Epoch 125/400
# 7/7 - 0s - loss: 7.5762e-05 - 5ms/epoch - 654us/step
# Epoch 126/400
# 7/7 - 0s - loss: 7.3971e-05 - 4ms/epoch - 585us/step
# Epoch 127/400
# 7/7 - 0s - loss: 7.3490e-05 - 4ms/epoch - 543us/step
# Epoch 128/400
# 7/7 - 0s - loss: 7.6379e-05 - 4ms/epoch - 554us/step
# Epoch 129/400
# 7/7 - 0s - loss: 7.5014e-05 - 4ms/epoch - 522us/step
# Epoch 130/400
# 7/7 - 0s - loss: 7.0247e-05 - 5ms/epoch - 664us/step
# Epoch 131/400
# 7/7 - 0s - loss: 7.2546e-05 - 4ms/epoch - 557us/step
# Epoch 132/400
# 7/7 - 0s - loss: 7.5064e-05 - 4ms/epoch - 621us/step
# Epoch 133/400
# 7/7 - 0s - loss: 7.4148e-05 - 4ms/epoch - 584us/step
# Epoch 134/400
# 7/7 - 0s - loss: 7.0132e-05 - 4ms/epoch - 547us/step
# Epoch 135/400
# 7/7 - 0s - loss: 6.8071e-05 - 4ms/epoch - 539us/step
# Epoch 136/400
# 7/7 - 0s - loss: 6.7140e-05 - 4ms/epoch - 517us/step
# Epoch 137/400
# 7/7 - 0s - loss: 6.8532e-05 - 4ms/epoch - 527us/step
# Epoch 138/400
# 7/7 - 0s - loss: 6.6147e-05 - 4ms/epoch - 548us/step
# Epoch 139/400
# 7/7 - 0s - loss: 6.6746e-05 - 4ms/epoch - 521us/step
# Epoch 140/400
# 7/7 - 0s - loss: 6.4532e-05 - 4ms/epoch - 580us/step
# Epoch 141/400
# 7/7 - 0s - loss: 6.3720e-05 - 4ms/epoch - 564us/step
# Epoch 142/400
# 7/7 - 0s - loss: 6.4535e-05 - 4ms/epoch - 539us/step
# Epoch 143/400
# 7/7 - 0s - loss: 6.5782e-05 - 4ms/epoch - 512us/step
# Epoch 144/400
# 7/7 - 0s - loss: 6.1930e-05 - 4ms/epoch - 623us/step
# Epoch 145/400
# 7/7 - 0s - loss: 6.2009e-05 - 4ms/epoch - 577us/step
# Epoch 146/400
# 7/7 - 0s - loss: 6.0532e-05 - 4ms/epoch - 537us/step
# Epoch 147/400
# 7/7 - 0s - loss: 6.1285e-05 - 4ms/epoch - 571us/step
# Epoch 148/400
# 7/7 - 0s - loss: 6.0139e-05 - 5ms/epoch - 649us/step
# Epoch 149/400
# 7/7 - 0s - loss: 6.0871e-05 - 4ms/epoch - 568us/step
# Epoch 150/400
# 7/7 - 0s - loss: 6.1634e-05 - 5ms/epoch - 672us/step
# Epoch 151/400
# 7/7 - 0s - loss: 5.7989e-05 - 5ms/epoch - 703us/step
# Epoch 152/400
# 7/7 - 0s - loss: 5.9665e-05 - 4ms/epoch - 558us/step
# Epoch 153/400
# 7/7 - 0s - loss: 5.9843e-05 - 5ms/epoch - 718us/step
# Epoch 154/400
# 7/7 - 0s - loss: 5.6882e-05 - 4ms/epoch - 585us/step
# Epoch 155/400
# 7/7 - 0s - loss: 6.3958e-05 - 4ms/epoch - 562us/step
# Epoch 156/400
# 7/7 - 0s - loss: 6.4104e-05 - 5ms/epoch - 647us/step
# Epoch 157/400
# 7/7 - 0s - loss: 6.6564e-05 - 4ms/epoch - 585us/step
# Epoch 158/400
# 7/7 - 0s - loss: 5.5521e-05 - 4ms/epoch - 556us/step
# Epoch 159/400
# 7/7 - 0s - loss: 7.6800e-05 - 4ms/epoch - 573us/step
# Epoch 160/400
# 7/7 - 0s - loss: 6.4900e-05 - 5ms/epoch - 739us/step
# Epoch 161/400
# 7/7 - 0s - loss: 6.4812e-05 - 4ms/epoch - 534us/step
# Epoch 162/400
# 7/7 - 0s - loss: 6.7529e-05 - 4ms/epoch - 516us/step
# Epoch 163/400
# 7/7 - 0s - loss: 6.5137e-05 - 4ms/epoch - 539us/step
# Epoch 164/400
# 7/7 - 0s - loss: 5.3981e-05 - 4ms/epoch - 511us/step
# Epoch 165/400
# 7/7 - 0s - loss: 5.0356e-05 - 4ms/epoch - 553us/step
# Epoch 166/400
# 7/7 - 0s - loss: 5.2334e-05 - 4ms/epoch - 540us/step
# Epoch 167/400
# 7/7 - 0s - loss: 5.2358e-05 - 4ms/epoch - 520us/step
# Epoch 168/400
# 7/7 - 0s - loss: 4.7639e-05 - 5ms/epoch - 648us/step
# Epoch 169/400
# 7/7 - 0s - loss: 5.1234e-05 - 4ms/epoch - 589us/step
# Epoch 170/400
# 7/7 - 0s - loss: 4.9116e-05 - 4ms/epoch - 531us/step
# Epoch 171/400
# 7/7 - 0s - loss: 5.0293e-05 - 4ms/epoch - 548us/step
# Epoch 172/400
# 7/7 - 0s - loss: 4.6687e-05 - 5ms/epoch - 651us/step
# Epoch 173/400
# 7/7 - 0s - loss: 5.0636e-05 - 4ms/epoch - 536us/step
# Epoch 174/400
# 7/7 - 0s - loss: 4.6193e-05 - 5ms/epoch - 651us/step
# Epoch 175/400
# 7/7 - 0s - loss: 4.8273e-05 - 4ms/epoch - 576us/step
# Epoch 176/400
# 7/7 - 0s - loss: 4.7620e-05 - 4ms/epoch - 537us/step
# Epoch 177/400
# 7/7 - 0s - loss: 4.6740e-05 - 4ms/epoch - 556us/step
# Epoch 178/400
# 7/7 - 0s - loss: 4.5832e-05 - 4ms/epoch - 572us/step
# Epoch 179/400
# 7/7 - 0s - loss: 4.6607e-05 - 4ms/epoch - 567us/step
# Epoch 180/400
# 7/7 - 0s - loss: 4.6343e-05 - 4ms/epoch - 527us/step
# Epoch 181/400
# 7/7 - 0s - loss: 4.5982e-05 - 4ms/epoch - 514us/step
# Epoch 182/400
# 7/7 - 0s - loss: 4.8147e-05 - 4ms/epoch - 565us/step
# Epoch 183/400
# 7/7 - 0s - loss: 4.2600e-05 - 4ms/epoch - 558us/step
# Epoch 184/400
# 7/7 - 0s - loss: 4.3971e-05 - 4ms/epoch - 528us/step
# Epoch 185/400
# 7/7 - 0s - loss: 4.3477e-05 - 5ms/epoch - 734us/step
# Epoch 186/400
# 7/7 - 0s - loss: 4.7697e-05 - 4ms/epoch - 605us/step
# Epoch 187/400
# 7/7 - 0s - loss: 4.8218e-05 - 4ms/epoch - 586us/step
# Epoch 188/400
# 7/7 - 0s - loss: 4.6128e-05 - 5ms/epoch - 678us/step
# Epoch 189/400
# 7/7 - 0s - loss: 4.3849e-05 - 5ms/epoch - 659us/step
# Epoch 190/400
# 7/7 - 0s - loss: 4.3000e-05 - 4ms/epoch - 596us/step
# Epoch 191/400
# 7/7 - 0s - loss: 4.1226e-05 - 4ms/epoch - 622us/step
# Epoch 192/400
# 7/7 - 0s - loss: 4.3837e-05 - 5ms/epoch - 715us/step
# Epoch 193/400
# 7/7 - 0s - loss: 4.4130e-05 - 5ms/epoch - 700us/step
# Epoch 194/400
# 7/7 - 0s - loss: 4.5419e-05 - 5ms/epoch - 767us/step
# Epoch 195/400
# 7/7 - 0s - loss: 4.1015e-05 - 5ms/epoch - 732us/step
# Epoch 196/400
# 7/7 - 0s - loss: 3.9452e-05 - 4ms/epoch - 557us/step
# Epoch 197/400
# 7/7 - 0s - loss: 4.0444e-05 - 5ms/epoch - 765us/step
# Epoch 198/400
# 7/7 - 0s - loss: 3.8678e-05 - 4ms/epoch - 640us/step
# Epoch 199/400
# 7/7 - 0s - loss: 3.8791e-05 - 4ms/epoch - 616us/step
# Epoch 200/400
# 7/7 - 0s - loss: 4.1391e-05 - 7ms/epoch - 965us/step
# Epoch 201/400
# 7/7 - 0s - loss: 3.9624e-05 - 4ms/epoch - 638us/step
# Epoch 202/400
# 7/7 - 0s - loss: 3.8192e-05 - 4ms/epoch - 607us/step
# Epoch 203/400
# 7/7 - 0s - loss: 4.0635e-05 - 6ms/epoch - 818us/step
# Epoch 204/400
# 7/7 - 0s - loss: 3.7140e-05 - 5ms/epoch - 657us/step
# Epoch 205/400
# 7/7 - 0s - loss: 3.7898e-05 - 5ms/epoch - 759us/step
# Epoch 206/400
# 7/7 - 0s - loss: 4.1022e-05 - 5ms/epoch - 681us/step
# Epoch 207/400
# 7/7 - 0s - loss: 3.9529e-05 - 4ms/epoch - 641us/step
# Epoch 208/400
# 7/7 - 0s - loss: 3.7672e-05 - 5ms/epoch - 749us/step
# Epoch 209/400
# 7/7 - 0s - loss: 3.8596e-05 - 4ms/epoch - 537us/step
# Epoch 210/400
# 7/7 - 0s - loss: 3.7331e-05 - 4ms/epoch - 601us/step
# Epoch 211/400
# 7/7 - 0s - loss: 3.7137e-05 - 5ms/epoch - 740us/step
# Epoch 212/400
# 7/7 - 0s - loss: 3.7828e-05 - 4ms/epoch - 602us/step
# Epoch 213/400
# 7/7 - 0s - loss: 4.1212e-05 - 5ms/epoch - 649us/step
# Epoch 214/400
# 7/7 - 0s - loss: 3.7737e-05 - 5ms/epoch - 724us/step
# Epoch 215/400
# 7/7 - 0s - loss: 3.6964e-05 - 5ms/epoch - 651us/step
# Epoch 216/400
# 7/7 - 0s - loss: 4.0842e-05 - 4ms/epoch - 552us/step
# Epoch 217/400
# 7/7 - 0s - loss: 3.7299e-05 - 5ms/epoch - 656us/step
# Epoch 218/400
# 7/7 - 0s - loss: 4.4332e-05 - 4ms/epoch - 620us/step
# Epoch 219/400
# 7/7 - 0s - loss: 3.6919e-05 - 4ms/epoch - 548us/step
# Epoch 220/400
# 7/7 - 0s - loss: 3.8070e-05 - 6ms/epoch - 833us/step
# Epoch 221/400
# 7/7 - 0s - loss: 4.1967e-05 - 4ms/epoch - 638us/step
# Epoch 222/400
# 7/7 - 0s - loss: 3.7853e-05 - 4ms/epoch - 563us/step
# Epoch 223/400
# 7/7 - 0s - loss: 4.4554e-05 - 6ms/epoch - 916us/step
# Epoch 224/400
# 7/7 - 0s - loss: 3.0427e-05 - 5ms/epoch - 660us/step
# Epoch 225/400
# 7/7 - 0s - loss: 4.1344e-05 - 4ms/epoch - 578us/step
# Epoch 226/400
# 7/7 - 0s - loss: 3.5956e-05 - 6ms/epoch - 879us/step
# Epoch 227/400
# 7/7 - 0s - loss: 3.4496e-05 - 4ms/epoch - 598us/step
# Epoch 228/400
# 7/7 - 0s - loss: 3.5007e-05 - 5ms/epoch - 648us/step
# Epoch 229/400
# 7/7 - 0s - loss: 3.3867e-05 - 6ms/epoch - 910us/step
# Epoch 230/400
# 7/7 - 0s - loss: 4.1279e-05 - 4ms/epoch - 598us/step
# Epoch 231/400
# 7/7 - 0s - loss: 3.2372e-05 - 4ms/epoch - 581us/step
# Epoch 232/400
# 7/7 - 0s - loss: 3.7712e-05 - 5ms/epoch - 651us/step
# Epoch 233/400
# 7/7 - 0s - loss: 3.5179e-05 - 4ms/epoch - 610us/step
# Epoch 234/400
# 7/7 - 0s - loss: 3.4053e-05 - 4ms/epoch - 593us/step
# Epoch 235/400
# 7/7 - 0s - loss: 3.4140e-05 - 5ms/epoch - 662us/step
# Epoch 236/400
# 7/7 - 0s - loss: 3.7734e-05 - 5ms/epoch - 654us/step
# Epoch 237/400
# 7/7 - 0s - loss: 4.2636e-05 - 4ms/epoch - 591us/step
# Epoch 238/400
# 7/7 - 0s - loss: 4.2994e-05 - 6ms/epoch - 807us/step
# Epoch 239/400
# 7/7 - 0s - loss: 3.7909e-05 - 5ms/epoch - 691us/step
# Epoch 240/400
# 7/7 - 0s - loss: 3.4762e-05 - 5ms/epoch - 676us/step
# Epoch 241/400
# 7/7 - 0s - loss: 3.1352e-05 - 5ms/epoch - 698us/step
# Epoch 242/400
# 7/7 - 0s - loss: 3.1549e-05 - 4ms/epoch - 633us/step
# Epoch 243/400
# 7/7 - 0s - loss: 3.3590e-05 - 4ms/epoch - 574us/step
# Epoch 244/400
# 7/7 - 0s - loss: 3.0313e-05 - 5ms/epoch - 757us/step
# Epoch 245/400
# 7/7 - 0s - loss: 3.2815e-05 - 4ms/epoch - 638us/step
# Epoch 246/400
# 7/7 - 0s - loss: 3.1838e-05 - 5ms/epoch - 697us/step
# Epoch 247/400
# 7/7 - 0s - loss: 3.1659e-05 - 5ms/epoch - 711us/step
# Epoch 248/400
# 7/7 - 0s - loss: 3.2383e-05 - 4ms/epoch - 617us/step
# Epoch 249/400
# 7/7 - 0s - loss: 3.0796e-05 - 4ms/epoch - 549us/step
# Epoch 250/400
# 7/7 - 0s - loss: 3.2698e-05 - 5ms/epoch - 689us/step
# Epoch 251/400
# 7/7 - 0s - loss: 3.2319e-05 - 4ms/epoch - 542us/step
# Epoch 252/400
# 7/7 - 0s - loss: 3.1354e-05 - 4ms/epoch - 541us/step
# Epoch 253/400
# 7/7 - 0s - loss: 3.2370e-05 - 5ms/epoch - 715us/step
# Epoch 254/400
# 7/7 - 0s - loss: 3.6289e-05 - 4ms/epoch - 584us/step
# Epoch 255/400
# 7/7 - 0s - loss: 3.4660e-05 - 4ms/epoch - 549us/step
# Epoch 256/400
# 7/7 - 0s - loss: 2.9293e-05 - 4ms/epoch - 524us/step
# Epoch 257/400
# 7/7 - 0s - loss: 3.6483e-05 - 28ms/epoch - 4ms/step
# Epoch 258/400
# 7/7 - 0s - loss: 2.9265e-05 - 15ms/epoch - 2ms/step
# Epoch 259/400
# 7/7 - 0s - loss: 3.0967e-05 - 5ms/epoch - 757us/step
# Epoch 260/400
# 7/7 - 0s - loss: 2.7366e-05 - 6ms/epoch - 854us/step
# Epoch 261/400
# 7/7 - 0s - loss: 3.0212e-05 - 5ms/epoch - 696us/step
# Epoch 262/400
# 7/7 - 0s - loss: 3.3029e-05 - 6ms/epoch - 848us/step
# Epoch 263/400
# 7/7 - 0s - loss: 2.8916e-05 - 5ms/epoch - 722us/step
# Epoch 264/400
# 7/7 - 0s - loss: 3.4005e-05 - 4ms/epoch - 533us/step
# Epoch 265/400
# 7/7 - 0s - loss: 2.9263e-05 - 6ms/epoch - 813us/step
# Epoch 266/400
# 7/7 - 0s - loss: 2.8312e-05 - 4ms/epoch - 562us/step
# Epoch 267/400
# 7/7 - 0s - loss: 3.2619e-05 - 4ms/epoch - 629us/step
# Epoch 268/400
# 7/7 - 0s - loss: 2.8488e-05 - 5ms/epoch - 748us/step
# Epoch 269/400
# 7/7 - 0s - loss: 3.8618e-05 - 5ms/epoch - 674us/step
# Epoch 270/400
# 7/7 - 0s - loss: 3.0878e-05 - 4ms/epoch - 564us/step
# Epoch 271/400
# 7/7 - 0s - loss: 2.9797e-05 - 6ms/epoch - 796us/step
# Epoch 272/400
# 7/7 - 0s - loss: 2.8718e-05 - 5ms/epoch - 654us/step
# Epoch 273/400
# 7/7 - 0s - loss: 2.8453e-05 - 7ms/epoch - 1ms/step
# Epoch 274/400
# 7/7 - 0s - loss: 3.1008e-05 - 5ms/epoch - 754us/step
# Epoch 275/400
# 7/7 - 0s - loss: 2.5504e-05 - 5ms/epoch - 763us/step
# Epoch 276/400
# 7/7 - 0s - loss: 2.8604e-05 - 6ms/epoch - 806us/step
# Epoch 277/400
# 7/7 - 0s - loss: 2.6463e-05 - 4ms/epoch - 605us/step
# Epoch 278/400
# 7/7 - 0s - loss: 2.7084e-05 - 4ms/epoch - 592us/step
# Epoch 279/400
# 7/7 - 0s - loss: 2.7147e-05 - 6ms/epoch - 832us/step
# Epoch 280/400
# 7/7 - 0s - loss: 2.6562e-05 - 5ms/epoch - 657us/step
# Epoch 281/400
# 7/7 - 0s - loss: 2.7355e-05 - 5ms/epoch - 652us/step
# Epoch 282/400
# 7/7 - 0s - loss: 2.5883e-05 - 4ms/epoch - 577us/step
# Epoch 283/400
# 7/7 - 0s - loss: 2.9564e-05 - 6ms/epoch - 827us/step
# Epoch 284/400
# 7/7 - 0s - loss: 2.6126e-05 - 9ms/epoch - 1ms/step
# Epoch 285/400
# 7/7 - 0s - loss: 2.6298e-05 - 5ms/epoch - 657us/step
# Epoch 286/400
# 7/7 - 0s - loss: 2.6854e-05 - 7ms/epoch - 982us/step
# Epoch 287/400
# 7/7 - 0s - loss: 2.6743e-05 - 4ms/epoch - 603us/step
# Epoch 288/400
# 7/7 - 0s - loss: 2.5998e-05 - 4ms/epoch - 590us/step
# Epoch 289/400
# 7/7 - 0s - loss: 2.6787e-05 - 6ms/epoch - 837us/step
# Epoch 290/400
# 7/7 - 0s - loss: 2.6132e-05 - 4ms/epoch - 576us/step
# Epoch 291/400
# 7/7 - 0s - loss: 2.5030e-05 - 4ms/epoch - 549us/step
# Epoch 292/400
# 7/7 - 0s - loss: 2.6620e-05 - 5ms/epoch - 706us/step
# Epoch 293/400
# 7/7 - 0s - loss: 2.5713e-05 - 4ms/epoch - 562us/step
# Epoch 294/400
# 7/7 - 0s - loss: 2.4750e-05 - 4ms/epoch - 564us/step
# Epoch 295/400
# 7/7 - 0s - loss: 2.8087e-05 - 6ms/epoch - 795us/step
# Epoch 296/400
# 7/7 - 0s - loss: 4.5912e-05 - 4ms/epoch - 558us/step
# Epoch 297/400
# 7/7 - 0s - loss: 3.0410e-05 - 4ms/epoch - 574us/step
# Epoch 298/400
# 7/7 - 0s - loss: 2.7834e-05 - 7ms/epoch - 1ms/step
# Epoch 299/400
# 7/7 - 0s - loss: 2.6278e-05 - 4ms/epoch - 588us/step
# Epoch 300/400
# 7/7 - 0s - loss: 2.9676e-05 - 4ms/epoch - 591us/step
# Epoch 301/400
# 7/7 - 0s - loss: 2.4533e-05 - 7ms/epoch - 1ms/step
# Epoch 302/400
# 7/7 - 0s - loss: 2.9786e-05 - 5ms/epoch - 695us/step
# Epoch 303/400
# 7/7 - 0s - loss: 2.6164e-05 - 7ms/epoch - 970us/step
# Epoch 304/400
# 7/7 - 0s - loss: 2.6487e-05 - 4ms/epoch - 604us/step
# Epoch 305/400
# 7/7 - 0s - loss: 2.7933e-05 - 4ms/epoch - 583us/step
# Epoch 306/400
# 7/7 - 0s - loss: 2.4566e-05 - 7ms/epoch - 1ms/step
# Epoch 307/400
# 7/7 - 0s - loss: 2.4022e-05 - 4ms/epoch - 622us/step
# Epoch 308/400
# 7/7 - 0s - loss: 2.5769e-05 - 4ms/epoch - 634us/step
# Epoch 309/400
# 7/7 - 0s - loss: 2.6256e-05 - 6ms/epoch - 865us/step
# Epoch 310/400
# 7/7 - 0s - loss: 2.2390e-05 - 4ms/epoch - 642us/step
# Epoch 311/400
# 7/7 - 0s - loss: 2.6816e-05 - 6ms/epoch - 856us/step
# Epoch 312/400
# 7/7 - 0s - loss: 2.3870e-05 - 4ms/epoch - 570us/step
# Epoch 313/400
# 7/7 - 0s - loss: 2.6170e-05 - 4ms/epoch - 555us/step
# Epoch 314/400
# 7/7 - 0s - loss: 2.4675e-05 - 5ms/epoch - 768us/step
# Epoch 315/400
# 7/7 - 0s - loss: 2.7185e-05 - 4ms/epoch - 639us/step
# Epoch 316/400
# 7/7 - 0s - loss: 2.5019e-05 - 4ms/epoch - 543us/step
# Epoch 317/400
# 7/7 - 0s - loss: 2.3278e-05 - 4ms/epoch - 627us/step
# Epoch 318/400
# 7/7 - 0s - loss: 2.4814e-05 - 4ms/epoch - 591us/step
# Epoch 319/400
# 7/7 - 0s - loss: 2.1013e-05 - 4ms/epoch - 580us/step
# Epoch 320/400
# 7/7 - 0s - loss: 2.6915e-05 - 4ms/epoch - 557us/step
# Epoch 321/400
# 7/7 - 0s - loss: 2.8155e-05 - 6ms/epoch - 819us/step
# Epoch 322/400
# 7/7 - 0s - loss: 2.7256e-05 - 4ms/epoch - 559us/step
# Epoch 323/400
# 7/7 - 0s - loss: 2.4825e-05 - 5ms/epoch - 697us/step
# Epoch 324/400
# 7/7 - 0s - loss: 2.7273e-05 - 5ms/epoch - 764us/step
# Epoch 325/400
# 7/7 - 0s - loss: 2.3002e-05 - 4ms/epoch - 559us/step
# Epoch 326/400
# 7/7 - 0s - loss: 2.5567e-05 - 4ms/epoch - 636us/step
# Epoch 327/400
# 7/7 - 0s - loss: 2.2988e-05 - 6ms/epoch - 927us/step
# Epoch 328/400
# 7/7 - 0s - loss: 2.2164e-05 - 5ms/epoch - 707us/step
# Epoch 329/400
# 7/7 - 0s - loss: 2.6320e-05 - 4ms/epoch - 595us/step
# Epoch 330/400
# 7/7 - 0s - loss: 2.3062e-05 - 6ms/epoch - 844us/step
# Epoch 331/400
# 7/7 - 0s - loss: 2.3180e-05 - 4ms/epoch - 615us/step
# Epoch 332/400
# 7/7 - 0s - loss: 2.2724e-05 - 4ms/epoch - 611us/step
# Epoch 333/400
# 7/7 - 0s - loss: 2.4205e-05 - 5ms/epoch - 691us/step
# Epoch 334/400
# 7/7 - 0s - loss: 2.2618e-05 - 4ms/epoch - 594us/step
# Epoch 335/400
# 7/7 - 0s - loss: 2.5057e-05 - 4ms/epoch - 554us/step
# Epoch 336/400
# 7/7 - 0s - loss: 2.6337e-05 - 5ms/epoch - 729us/step
# Epoch 337/400
# 7/7 - 0s - loss: 2.2196e-05 - 4ms/epoch - 594us/step
# Epoch 338/400
# 7/7 - 0s - loss: 2.3508e-05 - 4ms/epoch - 604us/step
# Epoch 339/400
# 7/7 - 0s - loss: 2.6635e-05 - 5ms/epoch - 689us/step
# Epoch 340/400
# 7/7 - 0s - loss: 2.9558e-05 - 4ms/epoch - 559us/step
# Epoch 341/400
# 7/7 - 0s - loss: 2.3823e-05 - 4ms/epoch - 533us/step
# Epoch 342/400
# 7/7 - 0s - loss: 2.7603e-05 - 5ms/epoch - 702us/step
# Epoch 343/400
# 7/7 - 0s - loss: 2.0152e-05 - 4ms/epoch - 520us/step
# Epoch 344/400
# 7/7 - 0s - loss: 2.5517e-05 - 4ms/epoch - 550us/step
# Epoch 345/400
# 7/7 - 0s - loss: 2.2495e-05 - 4ms/epoch - 579us/step
# Epoch 346/400
# 7/7 - 0s - loss: 2.3773e-05 - 4ms/epoch - 604us/step
# Epoch 347/400
# 7/7 - 0s - loss: 2.2685e-05 - 4ms/epoch - 547us/step
# Epoch 348/400
# 7/7 - 0s - loss: 2.2409e-05 - 4ms/epoch - 544us/step
# Epoch 349/400
# 7/7 - 0s - loss: 2.2414e-05 - 5ms/epoch - 680us/step
# Epoch 350/400
# 7/7 - 0s - loss: 2.6535e-05 - 4ms/epoch - 552us/step
# Epoch 351/400
# 7/7 - 0s - loss: 2.5826e-05 - 4ms/epoch - 555us/step
# Epoch 352/400
# 7/7 - 0s - loss: 2.7608e-05 - 4ms/epoch - 527us/step
# Epoch 353/400
# 7/7 - 0s - loss: 2.2959e-05 - 5ms/epoch - 696us/step
# Epoch 354/400
# 7/7 - 0s - loss: 2.2402e-05 - 4ms/epoch - 558us/step
# Epoch 355/400
# 7/7 - 0s - loss: 2.1184e-05 - 4ms/epoch - 562us/step
# Epoch 356/400
# 7/7 - 0s - loss: 2.3688e-05 - 4ms/epoch - 627us/step
# Epoch 357/400
# 7/7 - 0s - loss: 2.0050e-05 - 4ms/epoch - 600us/step
# Epoch 358/400
# 7/7 - 0s - loss: 3.8424e-05 - 4ms/epoch - 545us/step
# Epoch 359/400
# 7/7 - 0s - loss: 3.9232e-05 - 4ms/epoch - 549us/step
# Epoch 360/400
# 7/7 - 0s - loss: 2.8583e-05 - 5ms/epoch - 668us/step
# Epoch 361/400
# 7/7 - 0s - loss: 3.5427e-05 - 4ms/epoch - 551us/step
# Epoch 362/400
# 7/7 - 0s - loss: 2.2308e-05 - 4ms/epoch - 536us/step
# Epoch 363/400
# 7/7 - 0s - loss: 2.2403e-05 - 6ms/epoch - 787us/step
# Epoch 364/400
# 7/7 - 0s - loss: 2.0918e-05 - 5ms/epoch - 675us/step
# Epoch 365/400
# 7/7 - 0s - loss: 2.1358e-05 - 4ms/epoch - 616us/step
# Epoch 366/400
# 7/7 - 0s - loss: 2.2988e-05 - 5ms/epoch - 654us/step
# Epoch 367/400
# 7/7 - 0s - loss: 2.2052e-05 - 4ms/epoch - 620us/step
# Epoch 368/400
# 7/7 - 0s - loss: 2.0653e-05 - 4ms/epoch - 617us/step
# Epoch 369/400
# 7/7 - 0s - loss: 2.3057e-05 - 4ms/epoch - 634us/step
# Epoch 370/400
# 7/7 - 0s - loss: 2.0778e-05 - 4ms/epoch - 620us/step
# Epoch 371/400
# 7/7 - 0s - loss: 2.9853e-05 - 5ms/epoch - 650us/step
# Epoch 372/400
# 7/7 - 0s - loss: 2.2372e-05 - 5ms/epoch - 739us/step
# Epoch 373/400
# 7/7 - 0s - loss: 2.2732e-05 - 5ms/epoch - 709us/step
# Epoch 374/400
# 7/7 - 0s - loss: 2.4430e-05 - 5ms/epoch - 657us/step
# Epoch 375/400
# 7/7 - 0s - loss: 1.8427e-05 - 6ms/epoch - 786us/step
# Epoch 376/400
# 7/7 - 0s - loss: 2.6906e-05 - 5ms/epoch - 755us/step
# Epoch 377/400
# 7/7 - 0s - loss: 1.9856e-05 - 4ms/epoch - 581us/step
# Epoch 378/400
# 7/7 - 0s - loss: 2.3109e-05 - 5ms/epoch - 768us/step
# Epoch 379/400
# 7/7 - 0s - loss: 2.3155e-05 - 4ms/epoch - 598us/step
# Epoch 380/400
# 7/7 - 0s - loss: 2.0814e-05 - 4ms/epoch - 578us/step
# Epoch 381/400
# 7/7 - 0s - loss: 2.3831e-05 - 6ms/epoch - 894us/step
# Epoch 382/400
# 7/7 - 0s - loss: 2.8400e-05 - 4ms/epoch - 569us/step
# Epoch 383/400
# 7/7 - 0s - loss: 3.0713e-05 - 4ms/epoch - 632us/step
# Epoch 384/400
# 7/7 - 0s - loss: 2.0345e-05 - 7ms/epoch - 969us/step
# Epoch 385/400
# 7/7 - 0s - loss: 2.4615e-05 - 5ms/epoch - 737us/step
# Epoch 386/400
# 7/7 - 0s - loss: 1.7488e-05 - 10ms/epoch - 1ms/step
# Epoch 387/400
# 7/7 - 0s - loss: 2.2101e-05 - 5ms/epoch - 695us/step
# Epoch 388/400
# 7/7 - 0s - loss: 2.2989e-05 - 9ms/epoch - 1ms/step
# Epoch 389/400
# 7/7 - 0s - loss: 2.0211e-05 - 5ms/epoch - 724us/step
# Epoch 390/400
# 7/7 - 0s - loss: 1.9641e-05 - 4ms/epoch - 592us/step
# Epoch 391/400
# 7/7 - 0s - loss: 1.8084e-05 - 5ms/epoch - 724us/step
# Epoch 392/400
# 7/7 - 0s - loss: 2.6496e-05 - 4ms/epoch - 641us/step
# Epoch 393/400
# 7/7 - 0s - loss: 3.4762e-05 - 6ms/epoch - 808us/step
# Epoch 394/400
# 7/7 - 0s - loss: 1.6935e-05 - 4ms/epoch - 609us/step
# Epoch 395/400
# 7/7 - 0s - loss: 2.1528e-05 - 4ms/epoch - 572us/step
# Epoch 396/400
# 7/7 - 0s - loss: 1.8428e-05 - 4ms/epoch - 567us/step
# Epoch 397/400
# 7/7 - 0s - loss: 1.9159e-05 - 6ms/epoch - 856us/step
# Epoch 398/400
# 7/7 - 0s - loss: 2.2550e-05 - 4ms/epoch - 606us/step
# Epoch 399/400
# 7/7 - 0s - loss: 2.2886e-05 - 4ms/epoch - 629us/step
# Epoch 400/400
# 7/7 - 0s - loss: 2.3365e-05 - 7ms/epoch - 950us/step
# Train Score: 0.00 MSE (0.00 RMSE)
# Test Score: 0.00 MSE (0.02 RMSE)
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 15ms/step
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
combined = trainPredictPlot
for i in np.arange(len(trainPredictPlot)):
    if i>17:
        combined[i] = testPredictPlot[i]

# %%
plt.figure()
plt.semilogx(Prs_lat,ss_covg_lat,'o',label='kMC (With lateral interaction)')
plt.semilogx(Prs_non_lat,ss_covg_non_lat,'*',label='kMC (No lateral interaction)')
plt.semilogx(Prs_non_lat,MKM_SS_covg_NONLAT,'-',label='MKM isotherm')
# plt.semilogx(Prs_lat,MKM_SS_covg_LAT,'--',label='MKM_LAT_Fitted isotherm')
plt.semilogx(Prs_lat,combined,'--',label='Fitted LSTM')
plt.legend()
plt.title('CO adsorption_desorption isotherm')
plt.xlabel('Pressure, [bar]')
plt.ylabel('CO Coverage, [ML]')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
plt.figure()
plt.plot(Prs_lat,ss_covg_lat,'o',label='kMC (With lateral interaction)')
plt.plot(Prs_non_lat,ss_covg_non_lat,'*',label='kMC (No lateral interaction)')
plt.plot(Prs_non_lat,MKM_SS_covg_NONLAT,'-',label='MKM isotherm')
# plt.plot(trainPredictPlot)
# plt.plot(testPredictPlot)
# plt.plot(Prs_lat,combined,'--',label='MKM_LAT_Fitted isotherm')
plt.plot(Prs_lat,combined,'--',label='Fitted LSTM')
plt.legend()
plt.title('CO adsorption_desorption isotherm')
plt.xlabel('Pressure, [bar]')
plt.ylabel('CO Coverage, [ML]')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640.0000169542105">
